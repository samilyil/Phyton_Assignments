# %%
yatirim=1000
yatirim0=1000
gunluk_kar=12
yatirim *=gunluk_kar/100 #yatırımın 1. günde ettiği kar
gun1= yatirim0+yatirim #1.gün sonu toplam para
gun1s=gun1
gun1s*=gunluk_kar/100
gun2= gun1+gun1s
gun2s=gun2
gun2s*=gunluk_kar/100
gun3=gun2+gun2s
gun3s=gun3
gun3s*=gunluk_kar/100
gun4=gun3+gun3s
gun4s=gun4
gun4s*=gunluk_kar/100
gun5=gun4+gun4s
gun5s=gun5
gun5s*=gunluk_kar/100
gun6=gun5+gun5s
gun6s=gun6
gun6s*=gunluk_kar/100
gun7=gun6+gun6s

print("Hafta başında ",yatirim0,""" dolarlık bitcoin aldığımızda günde ortalama %""",gunluk_kar,""" kazançla, bir hafta boyunca """,
      "{:.2f}".format(gun7-yatirim0)," dolar kazanırdık",sep="")
# Out:
# Hafta başında 1000 dolarlık bitcoin aldığımızda günde ortalama %12 kazançla, bir hafta boyunca 1210.68 dolar kazanırdık

# %%
File_name=input("Please Enter a File Name:")
print("Your File Name is:",File_name)
# Out:
# Please Enter a File Name: First Attempt
# Your File Name is: First Attempt
